# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open('./experiments_configs/dataset.pickle', 'rb') as ds_fh:
    data, labels = pickle.load(ds_fh)

# %%
data
# Out:
# [array([[0.        , 0.        , 0.        , ..., 0.29445504, 0.29020691,
#          0.28963701],
#         [0.3255067 , 0.31805148, 0.31037377, ..., 0.30519842, 0.2915919 ,
#          0.29014897],
#         [0.31613837, 0.30975062, 0.30217444, ..., 0.32332514, 0.29629188,
#          0.29409478],
#         ...,
#         [0.29873156, 0.30492855, 0.31313929, ..., 0.31896451, 0.32931002,
#          0.33498216],
#         [0.29533075, 0.29939822, 0.30478757, ..., 0.32507876, 0.33691324,
#          0.34284005],
#         [0.29287221, 0.29530617, 0.29853114, ..., 0.        , 0.        ,
#          0.        ]]),
#  array([[0.        , 0.        , 0.        , ..., 0.53316933, 0.79596812,
#          0.09989166],
#         [0.31717048, 0.31357059, 0.30882469, ..., 0.51793901, 0.76899558,
#          0.91992583],
#         [0.32494987, 0.31945163, 0.31223259, ..., 0.46371874, 0.65254864,
#          0.76561007],
#         ...,
# ...

# %%
labels
# Out:
# ['snow',
#  'snow',
#  'ellipse',
#  'dipole',
#  'snow',
#  'dipole',
#  'ellipse',
#  'snow',
#  'dipole',
#  'ellipse',
#  'ellipse',
#  'dipole',
#  'ellipse',
#  'snow',
#  'ellipse',
#  'snow',
#  'dipole',
#  'dipole']

# %%
len(list(zip(data, labels)))
# Out:
# 18

# %%
len([_ for idx, (img, label) in enumerate(zip(data, labels))])
# Out:
# 18

# %%
plt.figure(figsize=(15, 20))
for idx, (img, label) in enumerate(zip(data, labels)):
    plt.subplot(6, 3, 1 + idx)
    plt.imshow(X=img, cmap="Greys")
    plt.title(label)
#plt.show()
